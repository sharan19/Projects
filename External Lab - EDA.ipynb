# %% [markdown]
# ##                                          HR DATA SET

# %% [markdown]
# Steps -
# 1. Import the necessary libraries
# 2. Load the dataset and explore it.
# 3. Count the male and female employees and plot it.
# 4. Count the employee attrition and plot it.
# 5. Make a stacked barplot for employee attrition based on gender.
# 6. Slice the DataFrame wrt Gender & Extract the average Income of Male and Female Employee.
# 7. Show how the monthly income is distributed.

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import csv

# %%
hr=pd.read_csv('HR.txt',delim_whitespace=True)

# %%
hr.head()
# Out:
#   Individual Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0       Ind1       Yes   41               1       1102           1
# 1       Ind2        No   49               2        279           2
# 2       Ind3       Yes   37               1       1373           2
# 3       Ind4        No   33               2       1392           2
# 4       Ind5        No   27               1        591           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                 1          2               1              1
# 1                 8          1               1              1
# 2                 2          2               6              1
# 3                 3          4               1              1
# 4                 2          1               2              1
#
#            ...           RelationshipSatisfaction  StandardHours  \
# 0          ...                                  1             80
# ...

# %%
# Printing the number of rows and columns in the dataset
print("Total number of rows in HR dataset are   :",hr.shape[0])
print("Total number of columns in HR dataset are:",hr.shape[1])
# Out:
# Total number of rows in HR dataset are   : 1470
# Total number of columns in HR dataset are: 35

# %%
#Finding datatypes 
hr.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
#counting number of Attrition 
hr.groupby(['Attrition']).size()
# Out:
# Attrition
# No     1233
# Yes     237
# dtype: int64

# %%
hr.loc[0]
# Out:
# Individual                   Ind1
# Attrition                     Yes
# Age                            41
# BusinessTravel                  1
# DailyRate                    1102
# Department                      1
# DistanceFromHome                1
# Education                       2
# EducationField                  1
# EmployeeCount                   1
# EmployeeNumber                  1
# EnvironmentSatisfaction         2
# Gender                          2
# HourlyRate                     94
# JobInvolvement                  3
# JobLevel                        2
# JobRole                         1
# JobSatisfaction                 4
# MaritalStatus                   1
# MonthlyIncome                5993
# MonthlyRate                 19479
# NumCompaniesWorked              8
# OverTime                        1
# PercentSalaryHike              11
# PerformanceRating               3
# RelationshipSatisfaction        1
# StandardHours                  80
# ...

# %%
 df1=hr.loc[lambda hr: hr['Gender'] == 1, :]
print("Male Employees average monthly salary:")    
df1.loc[:,'MonthlyIncome'].mean()
# Out:
# Male Employees average monthly salary
# 6380.507936507936

# %%
 df1=hr.loc[lambda hr: hr['Gender'] == 2, :]
print("Female Employees average monthly salary:")    
df1.loc[:,'MonthlyIncome'].mean()
# Out:
# Female Employees average monthly salary:
# 6686.566326530612

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
#Showing how the monthly income is distributed
hr['MonthlyIncome'].describe()
# Out:
# count     1470.000000
# mean      6502.931293
# std       4707.956783
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %%
fig, axs = plt.subplots(figsize = (10,10))
sns.distplot(hr["Gender"], hist_kws=None);
# Out:
# C:\Users\sharan\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#ploting attrition wrt Gender
hr.boxplot(column=['Gender'],by=['Attrition']);

# %%
# ploting employees attrition

fig, axs = plt.subplots(figsize = (10,10))
sns.boxplot(x = "Attrition", y = "YearsAtCompany", data = HR, ax=axs);

# %% [markdown]
# ## Iris dataset

# %%
iris=pd.read_csv('Iris.csv')

# %%
iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa

# %%
#data types

iris.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %%
#printing top 10 and bottom 10 samples
print("First 10 samples are \n",iris.head(10))
# Out:
# First 10 samples are
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# ...

# %%
print("Last 10 samples are\n",iris.tail(10))
# Out:
# Last 10 samples are
#       Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# ...

# %%
#Finding number of rows and columns in the data set
iris.shape
# Out:
# (150, 5)

# %%
#Set the index of the dataframe to be the first column
iris.set_index(['Sepal Length (in cm)'])
# Out:
#                       Sepal Width in (cm)  Petal length (in cm)  \
# Sepal Length (in cm)
# 5.1                                   3.5                   1.4
# 4.9                                   3.0                   1.4
# 4.7                                   3.2                   1.3
# 4.6                                   3.1                   1.5
# 5.0                                   3.6                   1.4
# 5.4                                   3.9                   1.7
# 4.6                                   3.4                   1.4
# 5.0                                   3.4                   1.5
# 4.4                                   2.9                   1.4
# 4.9                                   3.1                   1.5
# 5.4                                   3.7                   1.5
# 4.8                                   3.4                   1.6
# 4.8                                   3.0                   1.4
# ...

# %%
iris.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
#printing all rows in third column
iris.iloc[:,[2]]
# Out:
#      Petal length (in cm)
# 0                     1.4
# 1                     1.4
# 2                     1.3
# 3                     1.5
# 4                     1.4
# 5                     1.7
# 6                     1.4
# 7                     1.5
# 8                     1.4
# 9                     1.5
# 10                    1.5
# 11                    1.6
# 12                    1.4
# 13                    1.1
# 14                    1.2
# 15                    1.5
# 16                    1.3
# 17                    1.4
# 18                    1.7
# 19                    1.5
# 20                    1.7
# 21                    1.5
# 22                    1.0
# 23                    1.7
# 24                    1.9
# 25                    1.6
# 26                    1.6
# 27                    1.5
# 28                    1.4
# 29                    1.6
# ..                    ...
# 120                   5.7
# 121                   4.9
# 122                   6.7
# ...

# %%
#Print only the Sepal width and Sepal Length for first 10 rows 
iris.iloc[:10,:2]
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)
# 0                   5.1                  3.5
# 1                   4.9                  3.0
# 2                   4.7                  3.2
# 3                   4.6                  3.1
# 4                   5.0                  3.6
# 5                   5.4                  3.9
# 6                   4.6                  3.4
# 7                   5.0                  3.4
# 8                   4.4                  2.9
# 9                   4.9                  3.1

# %%
# Print all the columns of row which has class name "Iris-setosa"
iris.groupby(['Class']).get_group(('Iris-setosa'))
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                    5.1                  3.5                   1.4
# 1                    4.9                  3.0                   1.4
# 2                    4.7                  3.2                   1.3
# 3                    4.6                  3.1                   1.5
# 4                    5.0                  3.6                   1.4
# 5                    5.4                  3.9                   1.7
# 6                    4.6                  3.4                   1.4
# 7                    5.0                  3.4                   1.5
# 8                    4.4                  2.9                   1.4
# 9                    4.9                  3.1                   1.5
# 10                   5.4                  3.7                   1.5
# 11                   4.8                  3.4                   1.6
# 12                   4.8                  3.0                   1.4
# ...

# %%
# Finding product of sepal length and width. store the answer in sepalextra

iris['SepalExtra']=iris.loc[:,'Sepal Length (in cm)']*iris.loc[:,'Sepal Width in (cm)']
iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 10                    5.4                  3.7                   1.5
# 11                    4.8                  3.4                   1.6
# 12                    4.8                  3.0                   1.4
# ...

# %%
#Find out the mean and variance for each column but for class column
iris.select_dtypes(exclude='object').mean()
# Out:
# Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# SepalExtra              17.806533
# dtype: float64

# %%
iris.select_dtypes(exclude='object').var()
# Out:
# Sepal Length (in cm)     0.685694
# Sepal Width in (cm)      0.188004
# Petal length (in cm)     3.113179
# Petal width (in cm)      0.582414
# SepalExtra              11.348090
# dtype: float64

# %%
#Write a function that accepts two numbers as input and prints them 

def func(a,b):
    print (a,b)

# %%
#Pass the Sepal length and sepal width of 5th row and print the output
func(iris.loc[4,'Sepal Length (in cm)'],iris.loc[4,'Sepal Width in (cm)'])
# Out:
# 5.0 3.6

# %%
# Find the range of all the columns in the dataset
Iris.select_dtypes(exclude='object').max()-Iris.select_dtypes(exclude='object').min()
# Out:
# Sepal Length (in cm)    3.6
# Sepal Width in (cm)     2.4
# Petal length (in cm)    5.9
# Petal width (in cm)     2.4
# dtype: float64

# %%
# Sort the entire dataset according to the column Petal width
Iris.sort_values(by='Petal width (in cm)',ascending=True)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 32                    5.2                  4.1                   1.5
# 13                    4.3                  3.0                   1.1
# 37                    4.9                  3.1                   1.5
# 9                     4.9                  3.1                   1.5
# 12                    4.8                  3.0                   1.4
# 34                    4.9                  3.1                   1.5
# 0                     5.1                  3.5                   1.4
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# 30                    4.8                  3.1                   1.6
# 33                    5.5                  4.2                   1.4
# 36                    5.5                  3.5                   1.3
# ...

# %%
# Remove the new column "SepalExtra" from the dataframe

iris.drop("SepalExtra",axis=1)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 10                    5.4                  3.7                   1.5
# 11                    4.8                  3.4                   1.6
# 12                    4.8                  3.0                   1.4
# ...

# %%
# Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset" 

IrisSubset=iris.iloc[:10,:3]

# %%
IrisSubset
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
